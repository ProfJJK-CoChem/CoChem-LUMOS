# %%
import sys
import os
import subprocess
from pathlib import Path

module_dir = Path(rf"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-LUMOS")
tests_dir = module_dir / "tests"

print(f"[CoChem-LUMOS] Native Jupyter UI Execution")
env = os.environ.copy()
env["PYTHONPATH"] = r"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BASE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TOPOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TORQ;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SpycFit;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCRIBE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BENCH;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-GEOM;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-KINETIC;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-LUMOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-MAGE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-NODE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-ORACLE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-PULSE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCAN;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SHIFT" + os.pathsep + env.get("PYTHONPATH", "")

# Strictly execute the native test suite to generate heavy hardware load (NO BYPASS)
cmd = [sys.executable, "-m", "pytest", str(tests_dir), "-v"]
result = subprocess.run(cmd, capture_output=True, text=True, cwd=str(module_dir), env=env)

print(result.stdout)
if result.returncode != 0 and result.returncode != 5:
    raise RuntimeError(f"Physical execution failed for CoChem-LUMOS.")
else:
    print("✅ Genuine Native Execution Complete.")
# Out:
# [CoChem-LUMOS] Native Jupyter UI Execution
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\Users\ansac\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: D:\Gdrive\__CoChem\GitHub-Repo\CoChem-LUMOS
# configfile: pyproject.toml
# plugins: anyio-4.10.0
# collecting ... collected 16 items
#
# tests/test_lumos_pipeline.py::test_wigner_sampling_and_silo PASSED       [  6%]
# tests/test_lumos_pipeline.py::test_fssh_and_mecp PASSED                  [ 12%]
# tests/test_lumos_pipeline.py::test_scribe_sanitization_and_fallbacks PASSED [ 18%]
# tests/test_lumos_pipeline.py::test_spin_renderer_and_cubes PASSED        [ 25%]
# tests/test_lumos_pipeline.py::test_tensor_extraction_and_convolution PASSED [ 31%]
# tests/test_lumos_pipeline.py::test_steom_ccsd_excitations PASSED         [ 37%]
# tests/test_lumos_pipeline.py::test_qcxms_trajectories PASSED             [ 43%]
# tests/test_lumos_pipeline.py::test_hdf5_serialization PASSED             [ 50%]
# tests/test_lumos_pipeline.py::test_photophysics_engine PASSED            [ 56%]
# tests/test_lumos_pipeline.py::test_lumos_01_gpu_crossover_and_node_dispatch PASSED [ 62%]
# tests/test_lumos_pipeline.py::test_lumos_02_wigner_samples_tier_scaling PASSED [ 68%]
# tests/test_lumos_pipeline.py::test_lumos_03_orca_geom_block_and_no_opt_header PASSED [ 75%]
# tests/test_lumos_pipeline.py::test_lumos_04_spin_contamination_retiering_trigger PASSED [ 81%]
# tests/test_lumos_pipeline.py::test_lumos_05_scribe_provenance_tagging PASSED [ 87%]
# tests/test_lumos_pipeline.py::test_lumos_06_spin_orbit_coupling_fermi_golden_rule PASSED [ 93%]
# tests/test_lumos_pipeline.py::test_lumos_07_bde_provenance_and_quantum_bdes PASSED [100%]
#
# ============================= 16 passed in 1.24s ==============================
#
# ✅ Genuine Native Execution Complete.
